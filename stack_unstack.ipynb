# %%
import pandas as pd

# %%
df = pd.read_csv("https://cdncontribute.geeksforgeeks.org/wp-content/uploads/nba.csv")

# %%
df.sample(5)
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 410  Karl-Anthony Towns  Minnesota Timberwolves    32.0        C  20.0    7-0
# 107         Tarik Black      Los Angeles Lakers    28.0        C  24.0    6-9
# 79            Ian Clark   Golden State Warriors    21.0       SG  25.0    6-3
# 248    Andrew Goudelock         Houston Rockets     0.0       PG  27.0    6-3
# 167       Channing Frye     Cleveland Cavaliers     9.0       PF  33.0   6-11
#
#      Weight     College     Salary
# 410   244.0    Kentucky  5703600.0
# 107   250.0      Kansas   845059.0
# 79    175.0     Belmont   947276.0
# 248   200.0  Charleston   200600.0
# 167   255.0     Arizona  8193029.0

# %%
df.shape
# Out:
# (458, 9)

# %%
nba = df.stack()

# %%
nba
# Out:
# 0    Name         Avery Bradley
#      Team        Boston Celtics
#      Number                 0.0
#      Position                PG
#      Age                   25.0
#                       ...
# 456  Age                   26.0
#      Height                 7-0
#      Weight               231.0
#      College             Kansas
#      Salary            947276.0
# Length: 4018, dtype: object

# %% [markdown]
# # converte o dado ao formato original

# %%
reverter = nba.unstack()

# %%
reverter
# Out:
#               Name            Team Number Position   Age Height Weight  \
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0    6-2  180.0
# 1      Jae Crowder  Boston Celtics   99.0       SF  25.0    6-6  235.0
# 2     John Holland  Boston Celtics   30.0       SG  27.0    6-5  205.0
# 3      R.J. Hunter  Boston Celtics   28.0       SG  22.0    6-5  185.0
# 4    Jonas Jerebko  Boston Celtics    8.0       PF  29.0   6-10  231.0
# ..             ...             ...    ...      ...   ...    ...    ...
# 452     Trey Lyles       Utah Jazz   41.0       PF  20.0   6-10  234.0
# 453   Shelvin Mack       Utah Jazz    8.0       PG  26.0    6-3  203.0
# 454      Raul Neto       Utah Jazz   25.0       PG  24.0    6-1  179.0
# 455   Tibor Pleiss       Utah Jazz   21.0        C  26.0    7-3  256.0
# 456    Jeff Withey       Utah Jazz   24.0        C  26.0    7-0  231.0
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# ...
