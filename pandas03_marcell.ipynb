# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range("20220101", periods = 60, freq="D")

df1 = pd.DataFrame(np.random.randn(60,5), index = datas, columns = list("ABCDE"))

# %%
df1
# Out:
#                    A         B         C         D         E
# 2022-01-01  0.032220  1.653488  1.524655 -0.410939 -1.261822
# 2022-01-02 -0.185769  0.443763 -0.499169 -2.167667  0.709419
# 2022-01-03  0.877722 -0.549847 -0.086298 -1.101403 -0.094218
# 2022-01-04  0.971986 -0.113657 -1.178079 -0.432215 -0.913015
# 2022-01-05 -0.221100  0.876883 -0.246922 -0.088183  1.885315
# 2022-01-06  0.080140  0.508543  1.130949  1.622490 -0.753579
# 2022-01-07  0.229885  0.890652 -0.043144 -0.167281 -1.455542
# 2022-01-08  3.013957 -0.363184 -0.734456  1.022984  0.018469
# 2022-01-09 -0.323055  0.555448  0.570136  0.259144 -0.140506
# 2022-01-10 -0.537638  0.553633  1.415721 -0.231611 -0.346428
# 2022-01-11  0.284791  1.959233  1.603379  1.502010 -0.596069
# 2022-01-12  0.675413  0.470072  1.402715 -0.867919 -0.464085
# 2022-01-13 -1.208787  2.325698  0.323995  2.476061  1.096947
# 2022-01-14 -0.094760  1.095903 -1.462456  0.475515  0.024864
# ...

# %% [markdown]
# #Vizualizar as ultimas linhas

# %%
df1.tail(2)
# Out:
#                    A         B         C         D         E
# 2022-02-28  1.308104 -0.962153 -0.356978 -1.018043 -1.264806
# 2022-03-01  0.426978  0.881340 -1.504520 -1.585582  1.184420

# %% [markdown]
# #Acessar o indice

# %%
df1.index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-16',
#                '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-22', '2022-01-23', '2022-01-24',
#                '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28',
#                '2022-01-29', '2022-01-30', '2022-01-31', '2022-02-01',
#                '2022-02-02', '2022-02-03', '2022-02-04', '2022-02-05',
#                '2022-02-06', '2022-02-07', '2022-02-08', '2022-02-09',
#                '2022-02-10', '2022-02-11', '2022-02-12', '2022-02-13',
#                '2022-02-14', '2022-02-15', '2022-02-16', '2022-02-17',
#                '2022-02-18', '2022-02-19', '2022-02-20', '2022-02-21',
# ...

# %% [markdown]
# #Acessar as colunas

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
C = df1.columns

# %%
C
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %% [markdown]
# #Pegar somente os valores numericos

# %%
df1.to_numpy()
# Out:
# array([[ 3.22202893e-02,  1.65348758e+00,  1.52465525e+00,
#         -4.10939366e-01, -1.26182242e+00],
#        [-1.85769226e-01,  4.43762602e-01, -4.99168807e-01,
#         -2.16766727e+00,  7.09418762e-01],
#        [ 8.77722003e-01, -5.49847484e-01, -8.62977188e-02,
#         -1.10140307e+00, -9.42178735e-02],
#        [ 9.71985510e-01, -1.13657358e-01, -1.17807892e+00,
#         -4.32214633e-01, -9.13015355e-01],
#        [-2.21100207e-01,  8.76882784e-01, -2.46922451e-01,
#         -8.81832873e-02,  1.88531457e+00],
#        [ 8.01402872e-02,  5.08542814e-01,  1.13094941e+00,
#          1.62249046e+00, -7.53579329e-01],
#        [ 2.29884655e-01,  8.90651748e-01, -4.31444596e-02,
#         -1.67280661e-01, -1.45554189e+00],
#        [ 3.01395669e+00, -3.63183900e-01, -7.34456177e-01,
#          1.02298360e+00,  1.84691336e-02],
#        [-3.23055140e-01,  5.55448063e-01,  5.70135790e-01,
#          2.59144303e-01, -1.40506000e-01],
# ...

# %% [markdown]
# Transpoe colunas em em Linhas

# %% [markdown]
# #Obter a Transposta de um Conjunto de Dados

# %%
df1.T
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06  \
# A    0.032220   -0.185769    0.877722    0.971986   -0.221100    0.080140
# B    1.653488    0.443763   -0.549847   -0.113657    0.876883    0.508543
# C    1.524655   -0.499169   -0.086298   -1.178079   -0.246922    1.130949
# D   -0.410939   -2.167667   -1.101403   -0.432215   -0.088183    1.622490
# E   -1.261822    0.709419   -0.094218   -0.913015    1.885315   -0.753579
#
#    2022-01-07  2022-01-08  2022-01-09  2022-01-10  ...  2022-02-20  \
# A    0.229885    3.013957   -0.323055   -0.537638  ...   -0.537039
# B    0.890652   -0.363184    0.555448    0.553633  ...    0.210998
# C   -0.043144   -0.734456    0.570136    1.415721  ...    0.357109
# D   -0.167281    1.022984    0.259144   -0.231611  ...   -1.004207
# E   -1.455542    0.018469   -0.140506   -0.346428  ...    0.885807
#
#    2022-02-21  2022-02-22  2022-02-23  2022-02-24  2022-02-25  2022-02-26  \
# ...

# %%
df2 = pd.DataFrame({"A":7,
                  "B": pd.Timestamp('20190101'),
                  "C": pd.Series(1, index=list(range(4)), dtype='float32'),
                  "D": np.array([3] * 4, dtype='int32' ),
                  "E": pd.Categorical(["test","train","test","train"]),
                  "F": "Python" })

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                    7                    7                    7
# B  2019-01-01 00:00:00  2019-01-01 00:00:00  2019-01-01 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F               Python               Python               Python
#
#                      3
# A                    7
# B  2019-01-01 00:00:00
# C                  1.0
# D                    3
# E                train
# F               Python

# %% [markdown]
# #Cast dos Dados para Numpy

# %%
df2.to_numpy()
# Out:
# array([[7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'test', 'Python'],
#        [7, Timestamp('2019-01-01 00:00:00'), 1.0, 3, 'train', 'Python']],
#       dtype=object)
